# %%
import glob
import scipy
from PIL import Image
import numpy as np
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
PATH = '/content/drive/My Drive/2019-GAN-summer-school'
sys.path.insert(0, PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# full_size_images = glob.glob(f"{PATH}/images/*.jpg")
# print(len(full_size_images))

# %%
size = (112, 112)
# for im_path in full_size_images:
#     image = Image.open(im_path)
#     image = image.resize(size)
#     image.save(im_path.replace("images", "images_rezised").replace("jpg", "png"))

# %%
# Load dataset
paths = glob.glob(f"{PATH}/images_rezised/*.png")
print("N images:", len(paths))
images = []
for i, im_path in enumerate(paths):
  print(f"{i}/{len(paths)}")
  images.append(np.array(Image.open(im_path))[..., :3])
print(len(images))

# %%
X = np.stack(images)
print(X.shape)
print(X.min(), X.max())
# Out:
# (1495, 112, 112, 3)
# 0 255

# %%
import dcgan
import importlib
dcgan = importlib.reload(dcgan)
# Out:
# Using TensorFlow backend.

# %%
bigly_gan = dcgan.DCGAN(img_size=size[0], 
                        channels=X.shape[-1], 
                        n_fixed=4,
                        out_dir=f"{PATH}/output_images")

bigly_gan.train(X, epochs=10000, save_interval=25)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0815 11:11:33.761983 140320842237824 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0815 11:11:33.764070 140320842237824 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0815 11:11:33.766203 140320842237824 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...
